# %% [markdown]
# exo1 - JSON & Excel

# %%
import pandas as pd

# Lecture d’un fichier JSON classique
df_json = pd.read_json("../data/movies.json")

df_json.head()

# Si le fichier est au format JSON Lines :
# df_json = pd.read_json("../data/movies.json", lines=True)
# Out:
#    id                    title  views
# 0   1              Data Mining    100
# 1   2         Machine Learning    150
# 2   3  Artificial Intelligence    200

# %% [markdown]
#  Excel

# %%
import pandas as pd

path = "../data/sample.xlsx"

df_excel = pd.read_excel(path)

df_excel.head()
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %% [markdown]
# exo2 - Myql

# %%
# !pip install sqlalchemy pymysql

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:papa1234@localhost/datamining")

query = "SELECT * FROM etudiants WHERE G3 > 15"

df_sql = pd.read_sql(query, engine)

df_sql.head()
# Out:
# Empty DataFrame
# Columns: [id, G1, G2, G3]
# Index: []

# %% [markdown]
# Exo3 - API

# %%
pip install requests beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\papa sy\anaconda3\python.exe

# %%
import requests

response = requests.get("https://example.com")
print(response.status_code)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:790, in HTTPSConnection.connect(self)
#     788 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 790 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
# ...
